# %%
#First ML Project

# %% [markdown]
# # DECISION TREES (USING SKLEARN DECISIONTREEREGRESSOR)

# %%
#To predict house prices by training a decision tree model using skikit learn Decision Tree Regressor

# %%
#For More Help visit the below link:

# %% [markdown]
# https://www.kaggle.com/dansbecker/

# %%
from sklearn.treeee import DecisionTreeRegressor

# %%
import pandas as pd

# %%
melbourne_data = pd.read_csv('melb_data.csv')

# %%
melbourne_data.head() #This is not important ....I did it just to have a look at dataset and predict on my own
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0      ...            2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0      ...            1.0  2.0     120.0
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0           NaN        NaN        Yarra  -37.7996    144.9984
# 1          79.0     1900.0        Yarra  -37.8079    144.9934
# 2         150.0     1900.0        Yarra  -37.8093    144.9944
# 3           NaN        NaN        Yarra  -37.7969    144.9969
# 4         142.0     2014.0        Yarra  -37.8072    144.9941
#
#               Regionname Propertycount
# 0  Northern Metropolitan        4019.0
# 1  Northern Metropolitan        4019.0
# 2  Northern Metropolitan        4019.0
# 3  Northern Metropolitan        4019.0
# 4  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
#Lets say we want to predict prices of first 5 houses....based on the features Rooms,,Bathroom,Landsize,Lattitude,Longtitude

# %%
#First try describing the data to know about it

# %%
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# std        0.691712      0.962634    3990.669241    541.014538    37.273762
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1940.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  1999.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000   13580.000000
# mean     -37.809203    144.995216    7454.417378
# std        0.079260      0.103916    4378.581772
# min      -38.182550    144.431810     249.000000
# 25%      -37.856822    144.929600    4380.000000
# 50%      -37.802355    145.000100    6555.000000
# 75%      -37.756400    145.058305   10331.000000
# max      -37.408530    145.526350   21650.000000

# %%
melbourne_data.Price.describe()
# Out:
# count    1.358000e+04
# mean     1.075684e+06
# std      6.393107e+05
# min      8.500000e+04
# 25%      6.500000e+05
# 50%      9.030000e+05
# 75%      1.330000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %%
#or

# %%
melbourne_data['Price'].describe()
# Out:
# count    1.358000e+04
# mean     1.075684e+06
# std      6.393107e+05
# min      8.500000e+04
# 25%      6.500000e+05
# 50%      9.030000e+05
# 75%      1.330000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %%
#Selecting multiple columns at once into a new frame

# %%
melbourne_data[['Price','Longtitude']]
# Out:
#            Price  Longtitude
# 0      1480000.0   144.99840
# 1      1035000.0   144.99340
# 2      1465000.0   144.99440
# 3       850000.0   144.99690
# 4      1600000.0   144.99410
# 5       941000.0   144.99530
# 6      1876000.0   144.99930
# 7      1636000.0   144.99540
# 8       300000.0   144.99730
# 9      1097000.0   144.99890
# 10      700000.0   145.00670
# 11     1350000.0   144.99640
# 12      750000.0   144.99650
# 13     1172500.0   144.99730
# 14      441000.0   144.99880
# 15     1310000.0   144.99760
# 16     1200000.0   144.99300
# 17     1176500.0   144.99650
# 18      955000.0   144.99750
# 19      890000.0   145.00040
# 20     1330000.0   144.99520
# 21      900000.0   144.99590
# 22     1090000.0   144.99650
# 23      500000.0   144.99720
# 24     1100000.0   144.99770
# 25     1315000.0   144.99400
# 26      426000.0   144.99880
# 27     1447500.0   145.00010
# 28      457000.0   144.99650
# 29     1135000.0   144.99520
# ...          ...         ...
# 13550   595000.0   144.84445
# 13551   682000.0   144.80461
# 13552   640000.0   144.81529
# 13553  2720000.0   145.10352
# 13554  1715000.0   145.09035
# 13555  3100000.0   145.10919
# 13556   350000.0   144.65609
# 13557  1753000.0   145.16555
# 13558  1745000.0   145.10888
# 13559  1190000.0   145.11309
# 13560  1400000.0   145.11320
# 13561  1288000.0   145.10696
# 13562  1450000.0   144.99966
# 13563  1271000.0   145.01534
# 13564   540000.0   144.88002
# 13565  1263500.0   145.19276
# 13566  1250000.0   145.20051
# 13567  1316000.0   145.08341
# 13568   951000.0   145.23536
# 13569  1323000.0   145.22390
# 13570   970000.0   145.22805
# 13571  1330000.0   145.22116
# 13572   650000.0   145.07878
# 13573   635000.0   144.64789
# 13574   582000.0   144.89390
# 13575  1245000.0   145.16761
# 13576  1031000.0   144.87904
# 13577  1170000.0   144.88738
# 13578  2500000.0   144.89299
# 13579  1285000.0   144.88449
#
# [13580 rows x 2 columns]

# %%
#Building the predictors set

# %%
predictors_set = melbourne_data[['Rooms','Bathroom','Landsize','Lattitude','Longtitude']]

# %%
predictors_set
# Out:
#        Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 0          2       1.0     202.0  -37.79960   144.99840
# 1          2       1.0     156.0  -37.80790   144.99340
# 2          3       2.0     134.0  -37.80930   144.99440
# 3          3       2.0      94.0  -37.79690   144.99690
# 4          4       1.0     120.0  -37.80720   144.99410
# 5          2       1.0     181.0  -37.80410   144.99530
# 6          3       2.0     245.0  -37.80240   144.99930
# 7          2       1.0     256.0  -37.80600   144.99540
# 8          1       1.0       0.0  -37.80080   144.99730
# 9          2       1.0     220.0  -37.80100   144.99890
# 10         2       2.0       0.0  -37.81100   145.00670
# 11         3       2.0     214.0  -37.80850   144.99640
# 12         2       2.0       0.0  -37.80780   144.99650
# 13         2       1.0     195.0  -37.80840   144.99730
# 14         1       1.0       0.0  -37.80160   144.99880
# 15         2       1.0     238.0  -37.80900   144.99760
# 16         3       2.0     113.0  -37.80560   144.99300
# 17         3       1.0     138.0  -37.80210   144.99650
# 18         3       1.0     183.0  -37.80220   144.99750
# 19         2       1.0     150.0  -37.80110   145.00040
# 20         4       2.0     780.0  -37.80730   144.99520
# 21         3       2.0       0.0  -37.80930   144.99590
# 22         3       2.0    4290.0  -37.80780   144.99650
# 23         2       1.0       0.0  -37.80150   144.99720
# 24         2       2.0     124.0  -37.80790   144.99770
# 25         2       1.0     147.0  -37.80800   144.99400
# 26         1       1.0       0.0  -37.80160   144.99880
# 27         3       3.0     166.0  -37.80170   145.00010
# 28         1       1.0       0.0  -37.80780   144.99650
# 29         2       2.0      98.0  -37.80050   144.99520
# ...      ...       ...       ...        ...         ...
# 13550      3       1.0     589.0  -37.76599   144.84445
# 13551      4       1.0     534.0  -37.79161   144.80461
# 13552      3       1.0     616.0  -37.79798   144.81529
# 13553      4       3.0    1005.0  -37.82421   145.10352
# 13554      3       1.0     438.0  -37.83015   145.09035
# 13555      4       2.0     832.0  -37.83564   145.10919
# 13556      3       1.0     466.0  -37.86744   144.65609
# 13557      4       2.0     689.0  -37.76673   145.16555
# 13558      4       2.0     741.0  -37.75843   145.10888
# 13559      3       1.0     723.0  -37.76684   145.11309
# 13560      5       3.0     717.0  -37.76630   145.11320
# 13561      4       2.0     948.0  -37.76078   145.10696
# 13562      3       1.0     312.0  -37.75870   144.99966
# 13563      3       1.0     470.0  -37.75937   145.01534
# 13564      3       1.0     607.0  -37.69423   144.88002
# 13565      4       2.0     791.0  -37.84467   145.19276
# 13566      4       2.0     986.0  -37.84679   145.20051
# 13567      5       3.0     696.0  -37.73501   145.08341
# 13568      4       2.0     704.0  -37.85639   145.23536
# 13569      4       2.0     551.0  -37.87608   145.22390
# 13570      3       2.0     674.0  -37.88360   145.22805
# 13571      4       2.0     717.0  -37.86887   145.22116
# 13572      2       1.0     210.0  -37.70657   145.07878
# 13573      4       2.0     662.0  -37.89327   144.64789
# 13574      3       2.0     256.0  -37.67917   144.89390
# 13575      4       2.0     652.0  -37.90562   145.16761
# 13576      3       2.0     333.0  -37.85927   144.87904
# 13577      3       2.0     436.0  -37.85274   144.88738
# 13578      4       1.0     866.0  -37.85908   144.89299
# 13579      4       1.0     362.0  -37.81188   144.88449
#
# [13580 rows x 5 columns]

# %%
#LEts called it bby a common convention X

# %%
X = predictors_set

# %%
#LEts called price (to be predicted to be y)

# %%
y = melbourne_data['Price']#or melbourne_data.Price

# %%
#Initialize DecisionTreeRegressor into an object variable

# %%
#It would be our model to be trained

# %%
melbourne_model = DecisionTreeRegressor()

# %%
#Now Fit ypur dataset into this

# %%
melbourne_model.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
#This is the output that describes certain Parameters
